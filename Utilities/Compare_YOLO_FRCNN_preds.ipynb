# %%
import pickle
from sklearn.metrics import accuracy_score

# %%
pred_yolo = pickle.load(open("yoloconf.pk", "rb"))
# Out:
# /home/anvit/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: ResourceWarning: unclosed file <_io.BufferedReader name='yoloconf.pk'>
#   """Entry point for launching an IPython kernel.

# %%
pred_frcnn = pickle.load(open("frcnnconf.pk", "rb"))
# Out:
# /home/anvit/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: ResourceWarning: unclosed file <_io.BufferedReader name='frcnnconf.pk'>
#   """Entry point for launching an IPython kernel.

# %%
print(pred_yolo)
# Out:
# [0.05658754706382751, 0.125512242317199, 0.040541622787714, 0.137638509273529, 0.0509284064173698, 0.034450527280569, 0.1587062925100326, 0.02316846512258052, 0.020266119390726, 0.01175296492874622, 0.0780554339289665, 0.0238993652164936, 0.037377443164587, 0.01432856265455484, 0.00583766680210828, 0.00979926344007253, 0.0183929465711116, 0.01405769772827625, 0.32509061694145, 0.0174413491040468, 0.310525894165039, 0.0214113015681505, 0.1182086616754531, 0.01610205322504043, 0.23701499402523, 0.01595772057771682, 0.01610670983791351, 0.02512338384985923, 0.082524687051773, 0.0805009603500366, 0.1250730901956558, 0.2366474270820617, 0.0596064291894435, 0.207471832633018, 0.084835477173328, 0.2186767160892486, 0.05142980813980102, 0.02106295153498649, 0.0444693453609943, 0.0583880878984928, 0.0521596781909465, 0.1765830516815185, 0.0390162579715251, 0.01300147455185651, 0.005932517815381288, 0.1441172808408737, 0.01422696560621261, 0.2378851622343063, 0.2034264653921127, 0.020655917003
# ...

# %%
print(pred_frcnn)
# Out:
# [0.304, 0.869, 0.383, 0.884, 0.567, 0.511, 0.161, 0.052, 0.521, 0.086, 0, 0, 0, 0, 0.645, 0.784, 0.555, 0.817, 0.917, 0.155, 0.942, 0.091, 0.341, 0.277, 0.083, 0.204, 0, 0.077, 0.914, 0.277, 0.878, 0.675, 0.267, 0, 0.818, 0.845, 0.298, 0.568, 0.109, 0.674, 0.656, 0.852, 0.059, 0.186, 0.159, 0.734, 0.193, 0.828, 0.956, 0.41, 0.962, 0.656, 0.299, 0.57, 0.119, 0.545, 0.136, 0.91, 0.755, 0.773, 0.11, 0, 0.539, 0, 0.639, 0.761, 0.518, 0.717, 0.111, 0.639, 0.092, 0.235, 0.665, 0, 0.892, 0.326, 0.227, 0.924, 0.058, 0.954, 0.944, 0, 0.944, 0.287, 0.143, 0.051, 0.849, 0.09, 0.752, 0.293, 0.927, 0.89, 0.065, 0.881, 0.147, 0.71, 0.311, 0.357, 0.93, 0.58, 0.867, 0.075, 0.909, 0, 0.749, 0.086, 0.877, 0.94, 0.69, 0.863, 0.613, 0.101, 0.259, 0.055, 0.718, 0, 0.347, 0, 0, 0.179, 0.685, 0.224, 0, 0.223, 0.267, 0.325, 0.491, 0.444, 0.67, 0.628, 0.537, 0.227, 0.241, 0.285, 0, 0.149, 0.091, 0.145, 0.894, 0.676, 0.86, 0.961, 0.113, 0.961, 0.077, 0.793, 0.766, 0.32, 0.766, 0.365, 0.869, 0.758, 0.664, 0.72
# ...

# %%
print(len(pred_frcnn) == len(pred_yolo))
# Out:
# True

# %%
yolo = []
frcnn = []
for i in
